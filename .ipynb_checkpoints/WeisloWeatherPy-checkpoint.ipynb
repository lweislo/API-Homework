# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import openweathermapy as owm
from time import sleep
import seaborn as sbn
# Import API key
from api_keys import api_key
import warnings
warnings.filterwarnings('ignore')
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# # List for holding lat_lngs and cities
# lat_lngs = []
# cities = []
# # Create a set of random lat and lng combinations
# lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
# lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
# lat_lngs = zip(lats, lngs)
# # Identify nearest city for each lat, lng combination
# for lat_lng in lat_lngs:
#     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
#     # If the city is unique, then add it to a our cities list
#     if city not in cities:
#         cities.append(city)

# # Print the city count to confirm sufficient count
# len(cities)
# Out:
# 591

# %% [markdown]
# ## Break up the cities list into sets for API calls

# %%
# Create an array for the ranges of cities

# arr = np.arange(0, len(cities), round(len(cities)/12))
# arr= np.append(arr,len(cities))
# sets = []
# for i in range(len(arr)-1):
#     sets.append([arr[i], arr[i+1]])

# sets
# Out:
# [[0, 49],
#  [49, 98],
#  [98, 147],
#  [147, 196],
#  [196, 245],
#  [245, 294],
#  [294, 343],
#  [343, 392],
#  [392, 441],
#  [441, 490],
#  [490, 539],
#  [539, 588],
#  [588, 591]]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it\'s being processed (with the city number and city name).

# %%
# # Create a list to store the responses
# weather_data = []

# # Create a settings object with the API key and preferred units
# settings = {"units": "metric", "appid": api_key}

# # Create a list of parameters to keep
# summary = ["name","main.humidity", "main.temp_min","main.temp_max","wind.speed","clouds.all" ,"dt","sys.country", "sys.sunrise","sys.sunset","coord.lat", "coord.lon"]

# # Work with the log file to record the API calls/errors

# with open('logfile.txt', 'w') as log:  

#     for n in range(0, len(sets)-1):
#         # Generate a list of cities for each subset range
#         sub_cities = cities[sets[n][0]:sets[n][1]]

#         for city in sub_cities:
#             status = (f"Getting data for set number {n}: {city}... ")
#             log.write(status)
#             print(status)
#             #Perform the API call on OWM 
#             try:
#                 city_data = owm.get_current(city, **settings)
#                 weather_data.append(city_data)
                
#                 #Log the result
#                 msg = 'Success!\n'
#                 log.write(msg)
#                 print(msg)
#             except urllib.error.HTTPError:
#                 msg = 'City not found\n'
#                 log.write(msg)
#                 print(msg)
#         # Account is limted to 60 calls per minute. Pause between each set.        
#         sleep(55)

# data = [response(*summary) for response in weather_data]
# Out:
# Getting data for set number 0: arraial do cabo...
# Success!
#
# Getting data for set number 0: carnarvon...
# Success!
#
# Getting data for set number 0: mar del plata...
# Success!
#
# Getting data for set number 0: busselton...
# Success!
#
# Getting data for set number 0: albany...
# Success!
#
# Getting data for set number 0: ostrovnoy...
# Success!
#
# Getting data for set number 0: jamestown...
# Success!
#
# Getting data for set number 0: nikolskoye...
# Success!
#
# Getting data for set number 0: souillac...
# Success!
#
# Getting data for set number 0: rikitea...
# Success!
#
# Getting data for set number 0: tyukalinsk...
# Success!
#
# Getting data for set number 0: port hardy...
# Success!
#
# Getting data for set number 0: vaini...
# Success!
#
# Getting data for set number 0: westport...
# Success!
#
# Getting data for set number 0: fare...
# Success!
#
# Getting data for set number 0: kalabo...
# Success!
#
# Getting data for set number 0: new norfolk...
# Success!
#
# Getting data for set number 0: olivenca...
# Success!
#
# Getting data for set number 0: barentsburg...
# City not found
#
# Getting data for set number 0: muswellbrook...
# Success!
#
# Getting data for set number 0: hobart...
# Success!
#
# Getting data for set number 0: saskylakh...
# Success!
#
# Getting data for set number 0: staraya poltavka...
# Success!
#
# Getting data for set number 0: deputatskiy...
# Success!
#
# Getting data for set number 0: punta arenas...
# Success!
#
# Getting data for set number 0: atuona...
# Success!
#
# Getting data for set number 0: maldonado...
# Success!
#
# Getting data for set number 0: saint george...
# Success!
#
# Getting data for set number 0: tateyama...
# Success!
#
# Getting data for set number 0: coihaique...
# Success!
#
# Getting data for set number 0: vao...
# Success!
#
# Getting data for set number 0: upernavik...
# Success!
#
# Getting data for set number 0: dikson...
# Success!
#
# Getting data for set number 0: ban tak...
# Success!
#
# Getting data for set number 0: shubarshi...
# Success!
#
# Getting data for set number 0: nome...
# Success!
#
# Getting data for set number 0: camacha...
# Success!
#
# Getting data for set number 0: hasaki...
# Success!
#
# Getting data for set number 0: khonuu...
# City not found
#
# Getting data for set number 0: puerto ayora...
# Success!
#
# Getting data for set number 0: nizhneyansk...
# City not found
#
# Getting data for set number 0: leh...
# Success!
#
# Getting data for set number 0: hermanus...
# Success!
#
# Getting data for set number 0: praia da vitoria...
# Success!
#
# Getting data for set number 0: muros...
# Success!
#
# Getting data for set number 0: nanortalik...
# Success!
#
# Getting data for set number 0: port alfred...
# Success!
#
# Getting data for set number 0: tuktoyaktuk...
# Success!
#
# Getting data for set number 0: richards bay...
# Success!
#
# Getting data for set number 1: bluff...
# Success!
#
# Getting data for set number 1: san quintin...
# Success!
#
# Getting data for set number 1: pucallpa...
# Success!
#
# Getting data for set number 1: mataura...
# Success!
#
# Getting data for set number 1: tual...
# Success!
#
# Getting data for set number 1: saint-pierre...
# Success!
#
# Getting data for set number 1: marcona...
# City not found
#
# Getting data for set number 1: bengkulu...
# City not found
#
# Getting data for set number 1: hilo...
# Success!
#
# Getting data for set number 1: cayenne...
# Success!
#
# Getting data for set number 1: barrow...
# Success!
#
# Getting data for set number 1: provideniya...
# Success!
#
# Getting data for set number 1: kihei...
# Success!
#
# Getting data for set number 1: qaanaaq...
# Success!
#
# Getting data for set number 1: xingtai...
# Success!
#
# Getting data for set number 1: suntar...
# Success!
#
# Getting data for set number 1: gulshat...
# City not found
#
# Getting data for set number 1: chicama...
# Success!
#
# Getting data for set number 1: bell ville...
# Success!
#
# Getting data for set number 1: vaitupu...
# City not found
#
# Getting data for set number 1: zonguldak...
# Success!
#
# Getting data for set number 1: carrizal...
# Success!
#
# Getting data for set number 1: samusu...
# City not found
#
# Getting data for set number 1: severo-kurilsk...
# Success!
#
# Getting data for set number 1: cobija...
# Success!
#
# Getting data for set number 1: bambous virieux...
# Success!
#
# Getting data for set number 1: vostok...
# Success!
#
# Getting data for set number 1: ouadda...
# Success!
#
# Getting data for set number 1: tazovskiy...
# Success!
#
# Getting data for set number 1: kruisfontein...
# Success!
#
# Getting data for set number 1: sitka...
# Success!
#
# Getting data for set number 1: gamba...
# Success!
#
# Getting data for set number 1: artyk...
# City not found
#
# Getting data for set number 1: ketchikan...
# Success!
#
# Getting data for set number 1: geraldton...
# Success!
#
# Getting data for set number 1: yellowknife...
# Success!
#
# Getting data for set number 1: cabo san lucas...
# Success!
#
# Getting data for set number 1: victoria...
# Success!
#
# Getting data for set number 1: olafsvik...
# City not found
#
# Getting data for set number 1: avarua...
# Success!
#
# Getting data for set number 1: palabuhanratu...
# City not found
#
# Getting data for set number 1: port elizabeth...
# Success!
#
# Getting data for set number 1: constitucion...
# Success!
#
# Getting data for set number 1: itarema...
# Success!
#
# Getting data for set number 1: boyolangu...
# Success!
#
# Getting data for set number 1: chagda...
# City not found
#
# Getting data for set number 1: jinka...
# Success!
#
# Getting data for set number 1: camana...
# City not found
#
# Getting data for set number 1: saint anthony...
# Success!
#
# Getting data for set number 2: mys shmidta...
# City not found
#
# Getting data for set number 2: porto novo...
# Success!
#
# Getting data for set number 2: thompson...
# Success!
#
# Getting data for set number 2: borzya...
# Success!
#
# Getting data for set number 2: noumea...
# Success!
#
# Getting data for set number 2: honda...
# Success!
#
# Getting data for set number 2: khuzhir...
# Success!
#
# Getting data for set number 2: kodiak...
# Success!
#
# Getting data for set number 2: imbituba...
# Success!
#
# Getting data for set number 2: cape town...
# Success!
#
# Getting data for set number 2: madang...
# Success!
#
# Getting data for set number 2: ushuaia...
# Success!
#
# Getting data for set number 2: gorno-chuyskiy...
# City not found
#
# Getting data for set number 2: bethel...
# Success!
#
# Getting data for set number 2: tuatapere...
# Success!
#
# Getting data for set number 2: chokurdakh...
# Success!
#
# Getting data for set number 2: batemans bay...
# Success!
#
# Getting data for set number 2: kapaa...
# Success!
#
# Getting data for set number 2: kem...
# Success!
#
# Getting data for set number 2: auce...
# Success!
#
# Getting data for set number 2: albury...
# Success!
#
# Getting data for set number 2: erenhot...
# Success!
#
# Getting data for set number 2: santa fe...
# Success!
#
# Getting data for set number 2: alyangula...
# Success!
#
# Getting data for set number 2: attawapiskat...
# City not found
#
# Getting data for set number 2: talnakh...
# Success!
#
# Getting data for set number 2: brokopondo...
# Success!
#
# Getting data for set number 2: ponta do sol...
# Success!
#
# Getting data for set number 2: mount gambier...
# Success!
#
# Getting data for set number 2: milingimbi...
# City not found
#
# Getting data for set number 2: kuito...
# Success!
#
# Getting data for set number 2: katesh...
# Success!
#
# Getting data for set number 2: faanui...
# Success!
#
# Getting data for set number 2: tsihombe...
# City not found
#
# Getting data for set number 2: east london...
# Success!
#
# Getting data for set number 2: kahului...
# Success!
#
# Getting data for set number 2: rudnogorsk...
# Success!
#
# Getting data for set number 2: sentyabrskiy...
# City not found
#
# Getting data for set number 2: saleaula...
# City not found
#
# Getting data for set number 2: opuwo...
# Success!
#
# Getting data for set number 2: satipo...
# Success!
#
# Getting data for set number 2: ulaanbaatar...
# Success!
#
# Getting data for set number 2: makakilo city...
# Success!
#
# Getting data for set number 2: ballina...
# Success!
#
# Getting data for set number 2: roma...
# Success!
#
# Getting data for set number 2: reefton...
# City not found
#
# Getting data for set number 2: terrace...
# Success!
#
# Getting data for set number 2: sao jose de ribamar...
# Success!
#
# Getting data for set number 2: inirida...
# Success!
#
# Getting data for set number 3: lebu...
# Success!
#
# Getting data for set number 3: oranjestad...
# Success!
#
# Getting data for set number 3: saint-philippe...
# Success!
#
# Getting data for set number 3: akcakoca...
# Success!
#
# Getting data for set number 3: waingapu...
# Success!
#
# Getting data for set number 3: clyde river...
# Success!
#
# Getting data for set number 3: esperance...
# Success!
#
# Getting data for set number 3: port hedland...
# Success!
#
# Getting data for set number 3: ancud...
# Success!
#
# Getting data for set number 3: ambilobe...
# Success!
#
# Getting data for set number 3: shimoda...
# Success!
#
# Getting data for set number 3: isiolo...
# Success!
#
# Getting data for set number 3: contamana...
# Success!
#
# Getting data for set number 3: vrede...
# Success!
#
# Getting data for set number 3: taolanaro...
# City not found
#
# Getting data for set number 3: catia la mar...
# Success!
#
# Getting data for set number 3: arcata...
# Success!
#
# Getting data for set number 3: georgetown...
# Success!
#
# Getting data for set number 3: banda aceh...
# Success!
#
# Getting data for set number 3: sassandra...
# Success!
#
# Getting data for set number 3: vila velha...
# Success!
#
# Getting data for set number 3: jabinyanah...
# Success!
#
# Getting data for set number 3: elbistan...
# Success!
#
# Getting data for set number 3: necochea...
# Success!
#
# Getting data for set number 3: panzhihua...
# Success!
#
# Getting data for set number 3: rudnya...
# Success!
#
# Getting data for set number 3: logan lake...
# Success!
#
# Getting data for set number 3: khatanga...
# Success!
#
# Getting data for set number 3: mattru...
# Success!
#
# Getting data for set number 3: chuy...
# Success!
#
# Getting data for set number 3: flin flon...
# Success!
#
# Getting data for set number 3: yarmouth...
# Success!
#
# Getting data for set number 3: pokrov...
# Success!
#
# Getting data for set number 3: chumikan...
# Success!
#
# Getting data for set number 3: pingtung...
# Success!
#
# Getting data for set number 3: sarkand...
# Success!
#
# Getting data for set number 3: tarudant...
# City not found
#
# Getting data for set number 3: turbat...
# Success!
#
# Getting data for set number 3: saldanha...
# Success!
#
# Getting data for set number 3: iskateley...
# Success!
#
# Getting data for set number 3: narsaq...
# Success!
#
# Getting data for set number 3: callaguip...
# Success!
#
# Getting data for set number 3: qinzhou...
# Success!
#
# Getting data for set number 3: belushya guba...
# City not found
#
# Getting data for set number 3: north myrtle beach...
# Success!
#
# Getting data for set number 3: college...
# Success!
#
# Getting data for set number 3: bull savanna...
# Success!
#
# Getting data for set number 3: kita...
# Success!
#
# Getting data for set number 3: luganville...
# Success!
#
# Getting data for set number 4: pevek...
# Success!
#
# Getting data for set number 4: itaqui...
# Success!
#
# Getting data for set number 4: zhigansk...
# Success!
#
# Getting data for set number 4: kiama...
# Success!
#
# Getting data for set number 4: bredasdorp...
# Success!
#
# Getting data for set number 4: hofn...
# Success!
#
# Getting data for set number 4: nguiu...
# City not found
#
# Getting data for set number 4: ugoofaaru...
# Success!
#
# Getting data for set number 4: lavrentiya...
# Success!
#
# Getting data for set number 4: aksha...
# Success!
#
# Getting data for set number 4: camopi...
# Success!
#
# Getting data for set number 4: norman wells...
# Success!
#
# Getting data for set number 4: hithadhoo...
# Success!
#
# Getting data for set number 4: santana do livramento...
# Success!
#
# Getting data for set number 4: castro...
# Success!
#
# Getting data for set number 4: callaway...
# Success!
#
# Getting data for set number 4: illoqqortoormiut...
# City not found
#
# Getting data for set number 4: pangody...
# Success!
#
# Getting data for set number 4: ulladulla...
# Success!
#
# Getting data for set number 4: zuwarah...
# Success!
#
# Getting data for set number 4: isangel...
# Success!
#
# Getting data for set number 4: nenjiang...
# Success!
#
# Getting data for set number 4: carmo do rio claro...
# Success!
#
# Getting data for set number 4: zhuhai...
# Success!
#
# Getting data for set number 4: poya...
# Success!
#
# Getting data for set number 4: bonavista...
# Success!
#
# Getting data for set number 4: padang...
# Success!
#
# Getting data for set number 4: elat...
# Success!
#
# Getting data for set number 4: formoso do araguaia...
# City not found
#
# Getting data for set number 4: krasnoselkup...
# City not found
#
# Getting data for set number 4: gladstone...
# Success!
#
# Getting data for set number 4: longyearbyen...
# Success!
#
# Getting data for set number 4: chilca...
# Success!
#
# Getting data for set number 4: asau...
# City not found
#
# Getting data for set number 4: poum...
# Success!
#
# Getting data for set number 4: teya...
# Success!
#
# Getting data for set number 4: messina...
# Success!
#
# Getting data for set number 4: bara...
# Success!
#
# Getting data for set number 4: sokoni...
# Success!
#
# Getting data for set number 4: aktau...
# Success!
#
# Getting data for set number 4: viligili...
# City not found
#
# Getting data for set number 4: port-gentil...
# Success!
#
# Getting data for set number 4: puerto rondon...
# Success!
#
# Getting data for set number 4: wenatchee...
# Success!
#
# Getting data for set number 4: cururupu...
# Success!
#
# Getting data for set number 4: tiksi...
# Success!
#
# Getting data for set number 4: ulaangom...
# Success!
#
# Getting data for set number 4: okhotsk...
# Success!
#
# Getting data for set number 4: torbay...
# Success!
#
# Getting data for set number 5: matara...
# Success!
#
# Getting data for set number 5: el alto...
# Success!
#
# Getting data for set number 5: meulaboh...
# Success!
#
# Getting data for set number 5: ushtobe...
# Success!
#
# Getting data for set number 5: san patricio...
# Success!
#
# Getting data for set number 5: lixourion...
# Success!
#
# Getting data for set number 5: amaigbo...
# Success!
#
# Getting data for set number 5: inhambane...
# Success!
#
# Getting data for set number 5: ribeira grande...
# Success!
#
# Getting data for set number 5: srednekolymsk...
# Success!
#
# Getting data for set number 5: astana...
# Success!
#
# Getting data for set number 5: sorland...
# Success!
#
# Getting data for set number 5: butaritari...
# Success!
#
# Getting data for set number 5: khilok...
# Success!
#
# Getting data for set number 5: kirakira...
# Success!
#
# Getting data for set number 5: jibuti...
# City not found
#
# Getting data for set number 5: thunder bay...
# Success!
#
# Getting data for set number 5: hami...
# Success!
#
# Getting data for set number 5: lockhart...
# Success!
#
# Getting data for set number 5: cherskiy...
# Success!
#
# Getting data for set number 5: hamilton...
# Success!
#
# Getting data for set number 5: cidreira...
# Success!
#
# Getting data for set number 5: bibiani...
# Success!
#
# Getting data for set number 5: fairbanks...
# Success!
#
# Getting data for set number 5: onguday...
# Success!
#
# Getting data for set number 5: pangnirtung...
# Success!
#
# Getting data for set number 5: tecoanapa...
# Success!
#
# Getting data for set number 5: mahebourg...
# Success!
#
# Getting data for set number 5: kautokeino...
# Success!
#
# Getting data for set number 5: roald...
# Success!
#
# Getting data for set number 5: shingu...
# Success!
#
# Getting data for set number 5: maragogi...
# Success!
#
# Getting data for set number 5: eyrarbakki...
# Success!
#
# Getting data for set number 5: yulara...
# Success!
#
# Getting data for set number 5: tumannyy...
# City not found
#
# Getting data for set number 5: lolua...
# City not found
#
# Getting data for set number 5: beyneu...
# Success!
#
# Getting data for set number 5: pundaguitan...
# Success!
#
# Getting data for set number 5: iralaya...
# Success!
#
# Getting data for set number 5: gat...
# Success!
#
# Getting data for set number 5: selizharovo...
# Success!
#
# Getting data for set number 5: amderma...
# City not found
#
# Getting data for set number 5: yazoo city...
# Success!
#
# Getting data for set number 5: johnstown...
# Success!
#
# Getting data for set number 5: umzimvubu...
# City not found
#
# Getting data for set number 5: skalistyy...
# City not found
#
# Getting data for set number 5: bissau...
# Success!
#
# Getting data for set number 5: baruun-urt...
# Success!
#
# Getting data for set number 5: kaitangata...
# Success!
#
# Getting data for set number 6: alihe...
# Success!
#
# Getting data for set number 6: honiara...
# Success!
#
# Getting data for set number 6: tilichiki...
# Success!
#
# Getting data for set number 6: kaoma...
# Success!
#
# Getting data for set number 6: aflu...
# City not found
#
# Getting data for set number 6: lompoc...
# Success!
#
# Getting data for set number 6: zaraza...
# Success!
#
# Getting data for set number 6: kolvereid...
# Success!
#
# Getting data for set number 6: san cristobal...
# Success!
#
# Getting data for set number 6: micheweni...
# Success!
#
# Getting data for set number 6: asayita...
# City not found
#
# Getting data for set number 6: duz...
# City not found
#
# Getting data for set number 6: hokitika...
# Success!
#
# Getting data for set number 6: lebowakgomo...
# Success!
#
# Getting data for set number 6: codrington...
# Success!
#
# Getting data for set number 6: sao filipe...
# Success!
#
# Getting data for set number 6: falealupo...
# City not found
#
# Getting data for set number 6: fort nelson...
# Success!
#
# Getting data for set number 6: kimbe...
# Success!
#
# Getting data for set number 6: churachandpur...
# Success!
#
# Getting data for set number 6: mercedes...
# Success!
#
# Getting data for set number 6: bama...
# Success!
#
# Getting data for set number 6: nabire...
# Success!
#
# Getting data for set number 6: batagay-alyta...
# Success!
#
# Getting data for set number 6: vung tau...
# Success!
#
# Getting data for set number 6: dunedin...
# Success!
#
# Getting data for set number 6: raudeberg...
# Success!
#
# Getting data for set number 6: misratah...
# Success!
#
# Getting data for set number 6: mahadday weyne...
# City not found
#
# Getting data for set number 6: bilibino...
# Success!
#
# Getting data for set number 6: asbestos...
# Success!
#
# Getting data for set number 6: pacific grove...
# Success!
#
# Getting data for set number 6: georgiyevskoye...
# Success!
#
# Getting data for set number 6: labuhan...
# Success!
#
# Getting data for set number 6: kuche...
# City not found
#
# Getting data for set number 6: zhangye...
# Success!
#
# Getting data for set number 6: tasiilaq...
# Success!
#
# Getting data for set number 6: kavieng...
# Success!
#
# Getting data for set number 6: chapais...
# Success!
#
# Getting data for set number 6: bintulu...
# Success!
#
# Getting data for set number 6: abrego...
# Success!
#
# Getting data for set number 6: rawson...
# Success!
#
# Getting data for set number 6: trenggalek...
# Success!
#
# Getting data for set number 6: san carlos de bariloche...
# Success!
#
# Getting data for set number 6: merrill...
# Success!
#
# Getting data for set number 6: tidore...
# City not found
#
# Getting data for set number 6: finnsnes...
# Success!
#
# Getting data for set number 6: rocha...
# Success!
#
# Getting data for set number 6: farim...
# Success!
#
# Getting data for set number 7: kavaratti...
# Success!
#
# Getting data for set number 7: teodoro sampaio...
# Success!
#
# Getting data for set number 7: nauchnyy gorodok...
# Success!
#
# Getting data for set number 7: medicine hat...
# Success!
#
# Getting data for set number 7: galiwinku...
# City not found
#
# Getting data for set number 7: rio grande...
# Success!
#
# Getting data for set number 7: lumberton...
# Success!
#
# Getting data for set number 7: los llanos de aridane...
# Success!
#
# Getting data for set number 7: nyimba...
# Success!
#
# Getting data for set number 7: chimbote...
# Success!
#
# Getting data for set number 7: moshi...
# Success!
#
# Getting data for set number 7: yuanping...
# Success!
#
# Getting data for set number 7: disna...
# City not found
#
# Getting data for set number 7: mocuba...
# Success!
#
# Getting data for set number 7: christchurch...
# Success!
#
# Getting data for set number 7: aksu...
# Success!
#
# Getting data for set number 7: sinnamary...
# Success!
#
# Getting data for set number 7: bathsheba...
# Success!
#
# Getting data for set number 7: marawi...
# Success!
#
# Getting data for set number 7: leningradskiy...
# Success!
#
# Getting data for set number 7: the valley...
# Success!
#
# Getting data for set number 7: ossora...
# Success!
#
# Getting data for set number 7: bukama...
# Success!
#
# Getting data for set number 7: grindavik...
# Success!
#
# Getting data for set number 7: nastola...
# Success!
#
# Getting data for set number 7: jabiru...
# City not found
#
# Getting data for set number 7: port lincoln...
# Success!
#
# Getting data for set number 7: pyshma...
# Success!
#
# Getting data for set number 7: haapiti...
# Success!
#
# Getting data for set number 7: stromness...
# Success!
#
# Getting data for set number 7: sundsvall...
# Success!
#
# Getting data for set number 7: gizo...
# Success!
#
# Getting data for set number 7: malatya...
# City not found
#
# Getting data for set number 7: bartica...
# Success!
#
# Getting data for set number 7: cascas...
# Success!
#
# Getting data for set number 7: ndele...
# City not found
#
# Getting data for set number 7: babushkin...
# Success!
#
# Getting data for set number 7: marzuq...
# Success!
#
# Getting data for set number 7: wembley...
# Success!
#
# Getting data for set number 7: matveyevka...
# Success!
#
# Getting data for set number 7: iqaluit...
# Success!
#
# Getting data for set number 7: touros...
# Success!
#
# Getting data for set number 7: pyapon...
# Success!
#
# Getting data for set number 7: imeni morozova...
# Success!
#
# Getting data for set number 7: rajura...
# Success!
#
# Getting data for set number 7: ekhabi...
# Success!
#
# Getting data for set number 7: miraflores...
# Success!
#
# Getting data for set number 7: masaka...
# Success!
#
# Getting data for set number 7: podgorenskiy...
# Success!
#
# Getting data for set number 8: pisco...
# Success!
#
# Getting data for set number 8: atikokan...
# Success!
#
# Getting data for set number 8: ilulissat...
# Success!
#
# Getting data for set number 8: puerto cabezas...
# Success!
#
# Getting data for set number 8: laguna...
# Success!
#
# Getting data for set number 8: flinders...
# Success!
#
# Getting data for set number 8: lagoa...
# Success!
#
# Getting data for set number 8: atar...
# Success!
#
# Getting data for set number 8: krasnyy profintern...
# Success!
#
# Getting data for set number 8: santiago del estero...
# Success!
#
# Getting data for set number 8: coahuayana...
# Success!
#
# Getting data for set number 8: pringsewu...
# Success!
#
# Getting data for set number 8: whitecourt...
# Success!
#
# Getting data for set number 8: charters towers...
# Success!
#
# Getting data for set number 8: saint-joseph...
# Success!
#
# Getting data for set number 8: esil...
# Success!
#
# Getting data for set number 8: celendin...
# Success!
#
# Getting data for set number 8: waverley...
# Success!
#
# Getting data for set number 8: stephenville...
# Success!
#
# Getting data for set number 8: luba...
# Success!
#
# Getting data for set number 8: monrovia...
# Success!
#
# Getting data for set number 8: cabedelo...
# Success!
#
# Getting data for set number 8: ranong...
# Success!
#
# Getting data for set number 8: korla...
# City not found
#
# Getting data for set number 8: odweyne...
# City not found
#
# Getting data for set number 8: usinsk...
# Success!
#
# Getting data for set number 8: saint stephen...
# Success!
#
# Getting data for set number 8: sfantu gheorghe...
# Success!
#
# Getting data for set number 8: alice springs...
# Success!
#
# Getting data for set number 8: margate...
# Success!
#
# Getting data for set number 8: nibbar...
# Success!
#
# Getting data for set number 8: labuan...
# Success!
#
# Getting data for set number 8: sao felix do xingu...
# Success!
#
# Getting data for set number 8: ozark...
# Success!
#
# Getting data for set number 8: lasa...
# Success!
#
# Getting data for set number 8: cairns...
# Success!
#
# Getting data for set number 8: floro...
# Success!
#
# Getting data for set number 8: kirensk...
# Success!
#
# Getting data for set number 8: nyurba...
# Success!
#
# Getting data for set number 8: port-cartier...
# Success!
#
# Getting data for set number 8: khanpur...
# Success!
#
# Getting data for set number 8: airai...
# Success!
#
# Getting data for set number 8: formosa do rio preto...
# Success!
#
# Getting data for set number 8: phu ly...
# Success!
#
# Getting data for set number 8: katsuura...
# Success!
#
# Getting data for set number 8: guerrero negro...
# Success!
#
# Getting data for set number 8: auki...
# Success!
#
# Getting data for set number 8: namatanai...
# Success!
#
# Getting data for set number 8: faya...
# Success!
#
# Getting data for set number 9: kununurra...
# Success!
#
# Getting data for set number 9: sekoma...
# Success!
#
# Getting data for set number 9: aguimes...
# Success!
#
# Getting data for set number 9: cocachacra...
# Success!
#
# Getting data for set number 9: san juan...
# Success!
#
# Getting data for set number 9: sisimiut...
# Success!
#
# Getting data for set number 9: tura...
# Success!
#
# Getting data for set number 9: udachnyy...
# Success!
#
# Getting data for set number 9: vardo...
# Success!
#
# Getting data for set number 9: russell...
# Success!
#
# Getting data for set number 9: wanaka...
# Success!
#
# Getting data for set number 9: coquimbo...
# Success!
#
# Getting data for set number 9: alappuzha...
# City not found
#
# Getting data for set number 9: bur gabo...
# City not found
#
# Getting data for set number 9: matinha...
# Success!
#
# Getting data for set number 9: sur...
# Success!
#
# Getting data for set number 9: bousso...
# City not found
#
# Getting data for set number 9: mackay...
# Success!
#
# Getting data for set number 9: yar-sale...
# Success!
#
# Getting data for set number 9: jaciara...
# Success!
#
# Getting data for set number 9: halifax...
# Success!
#
# Getting data for set number 9: mendahara...
# City not found
#
# Getting data for set number 9: dhidhdhoo...
# Success!
#
# Getting data for set number 9: tigil...
# Success!
#
# Getting data for set number 9: fortuna...
# Success!
#
# Getting data for set number 9: boueni...
# Success!
#
# Getting data for set number 9: yinchuan...
# Success!
#
# Getting data for set number 9: maniitsoq...
# Success!
#
# Getting data for set number 9: monroe...
# Success!
#
# Getting data for set number 9: mount isa...
# Success!
#
# Getting data for set number 9: lorengau...
# Success!
#
# Getting data for set number 9: mizdah...
# Success!
#
# Getting data for set number 9: moses lake...
# Success!
#
# Getting data for set number 9: vestmannaeyjar...
# Success!
#
# Getting data for set number 9: malazgirt...
# Success!
#
# Getting data for set number 9: bilma...
# Success!
#
# Getting data for set number 9: jacareacanga...
# Success!
#
# Getting data for set number 9: naze...
# Success!
#
# Getting data for set number 9: portland...
# Success!
#
# Getting data for set number 9: benicarlo...
# Success!
#
# Getting data for set number 9: yanam...
# Success!
#
# Getting data for set number 9: jutai...
# Success!
#
# Getting data for set number 9: sao joao da barra...
# Success!
#
# Getting data for set number 9: beaumont...
# Success!
#
# Getting data for set number 9: wahran...
# City not found
#
# Getting data for set number 9: bourail...
# Success!
#
# Getting data for set number 9: port blair...
# Success!
#
# Getting data for set number 9: manta...
# Success!
#
# Getting data for set number 9: tongliao...
# Success!
#
# Getting data for set number 10: kharabali...
# Success!
#
# Getting data for set number 10: ozgon...
# City not found
#
# Getting data for set number 10: cap malheureux...
# Success!
#
# Getting data for set number 10: seymchan...
# Success!
#
# Getting data for set number 10: taltal...
# Success!
#
# Getting data for set number 10: orasac...
# Success!
#
# Getting data for set number 10: ust-tsilma...
# Success!
#
# Getting data for set number 10: sironko...
# Success!
#
# Getting data for set number 10: peniche...
# Success!
#
# Getting data for set number 10: sola...
# Success!
#
# Getting data for set number 10: savinka...
# Success!
#
# Getting data for set number 10: ariquemes...
# Success!
#
# Getting data for set number 10: rudbar...
# City not found
#
# Getting data for set number 10: alofi...
# Success!
#
# Getting data for set number 10: getulio vargas...
# Success!
#
# Getting data for set number 10: ahuimanu...
# Success!
#
# Getting data for set number 10: felidhoo...
# City not found
#
# Getting data for set number 10: athabasca...
# Success!
#
# Getting data for set number 10: catalina foothills...
# Success!
#
# Getting data for set number 10: aswan...
# Success!
#
# Getting data for set number 10: karaul...
# City not found
#
# Getting data for set number 10: oyama...
# Success!
#
# Getting data for set number 10: omboue...
# Success!
#
# Getting data for set number 10: joshimath...
# Success!
#
# Getting data for set number 10: neryungri...
# Success!
#
# Getting data for set number 10: rio gallegos...
# Success!
#
# Getting data for set number 10: frolovo...
# Success!
#
# Getting data for set number 10: coxim...
# Success!
#
# Getting data for set number 10: southbridge...
# Success!
#
# Getting data for set number 10: quesnel...
# Success!
#
# Getting data for set number 10: laiwu...
# Success!
#
# Getting data for set number 10: manzanillo...
# Success!
#
# Getting data for set number 10: jiblah...
# Success!
#
# Getting data for set number 10: hualmay...
# Success!
#
# Getting data for set number 10: piacabucu...
# Success!
#
# Getting data for set number 10: bardiyah...
# City not found
#
# Getting data for set number 10: kontagora...
# Success!
#
# Getting data for set number 10: palma...
# Success!
#
# Getting data for set number 10: alenquer...
# Success!
#
# Getting data for set number 10: agadir...
# Success!
#
# Getting data for set number 10: sataua...
# City not found
#
# Getting data for set number 10: golspie...
# Success!
#
# Getting data for set number 10: xining...
# Success!
#
# Getting data for set number 10: pendleton...
# Success!
#
# Getting data for set number 10: bandarbeyla...
# Success!
#
# Getting data for set number 10: mananjary...
# Success!
#
# Getting data for set number 10: klaksvik...
# Success!
#
# Getting data for set number 10: labutta...
# City not found
#
# Getting data for set number 10: amazar...
# Success!
#
# Getting data for set number 11: quepos...
# Success!
#
# Getting data for set number 11: paita...
# Success!
#
# Getting data for set number 11: luderitz...
# Success!
#
# Getting data for set number 11: shizunai...
# Success!
#
# Getting data for set number 11: skibbereen...
# Success!
#
# Getting data for set number 11: rodez...
# Success!
#
# Getting data for set number 11: takoradi...
# Success!
#
# Getting data for set number 11: kungalv...
# Success!
#
# Getting data for set number 11: harper...
# Success!
#
# Getting data for set number 11: santiago de cao...
# Success!
#
# Getting data for set number 11: karkaralinsk...
# City not found
#
# Getting data for set number 11: berlevag...
# Success!
#
# Getting data for set number 11: altena...
# Success!
#
# Getting data for set number 11: ghoti...
# Success!
#
# Getting data for set number 11: egvekinot...
# Success!
#
# Getting data for set number 11: quilmana...
# Success!
#
# Getting data for set number 11: sao jose da coroa grande...
# Success!
#
# Getting data for set number 11: siuna...
# Success!
#
# Getting data for set number 11: kristiansund...
# Success!
#
# Getting data for set number 11: houma...
# Success!
#
# Getting data for set number 11: sioux lookout...
# Success!
#
# Getting data for set number 11: kapuskasing...
# Success!
#
# Getting data for set number 11: bandiagara...
# Success!
#
# Getting data for set number 11: vila franca do campo...
# Success!
#
# Getting data for set number 11: port moresby...
# Success!
#
# Getting data for set number 11: botro...
# Success!
#
# Getting data for set number 11: naifaru...
# Success!
#
# Getting data for set number 11: tiarei...
# Success!
#
# Getting data for set number 11: mbalmayo...
# Success!
#
# Getting data for set number 11: chara...
# Success!
#
# Getting data for set number 11: ituni...
# City not found
#
# Getting data for set number 11: coaldale...
# Success!
#
# Getting data for set number 11: uyuni...
# Success!
#
# Getting data for set number 11: mosquera...
# Success!
#
# Getting data for set number 11: la ronge...
# Success!
#
# Getting data for set number 11: jiupu...
# Success!
#
# Getting data for set number 11: caravelas...
# Success!
#
# Getting data for set number 11: guanica...
# Success!
#
# Getting data for set number 11: murchison...
# Success!
#
# Getting data for set number 11: anloga...
# Success!
#
# Getting data for set number 11: guaratinga...
# City not found
#
# Getting data for set number 11: patos de minas...
# Success!
#
# Getting data for set number 11: rovnoye...
# Success!
#
# Getting data for set number 11: cornwall...
# Success!
#
# Getting data for set number 11: minturno...
# Success!
#
# Getting data for set number 11: przhevalskoye...
# Success!
#
# Getting data for set number 11: lalmanir hat...
# City not found
#
# Getting data for set number 11: poli...
# Success!
#
# Getting data for set number 11: klyuchi...
# Success!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# column_names = ["City","Humidity", "Min Temp","Max Temp","Wind Speed","Cloudiness","Date","Country","Sunrise","Sunset","Lat","Lon"]

# weather_data = pd.DataFrame(data, columns=column_names)
# weather_data.set_index('City')
# weather_data.to_csv('test.csv', encoding='UTF-8', header=True)

# %%
#For offline analysis, go back to the original csv file
weather_data = pd.read_csv('test.csv', encoding='UTF-8', index_col=0)
# weather_data = pd.DataFrame(data)
weather_data['Daytime'] = ''

weather_data.reset_index(drop=True)
weather_data.head()
# Out:
#               City  Humidity  Min Temp  Max Temp  Wind Speed  Cloudiness  \
# 0  Arraial do Cabo        49     31.00     33.00        6.20           0
# 1        Carnarvon        11     31.43     31.43        5.01          80
# 2    Mar del Plata        38     20.48     20.48        9.96          32
# 3        Busselton       100     19.40     19.40       10.86           0
# 4           Albany        55    -13.00     -8.30        3.60          75
#
#          Date Country     Sunrise      Sunset    Lat     Lon Daytime
# 0  1546869600      BR  1546848622  1546897113 -22.97  -42.02
# 1  1546872328      ZA  1546832178  1546882753 -30.97   22.13
# 2  1546872328      AR  1546850905  1546907055 -46.43  -67.52
# 3  1546872328      AU  1546809400  1546860770 -33.64  115.35
# 4  1546869240      US  1546863893  1546897101  42.65  -73.75

# %%
for i in range(0,len(weather_data)):
    if (weather_data.iloc[i,6] - weather_data.iloc[i,8]) >= 0 and (weather_data.iloc[i,6] - weather_data.iloc[i,9]) < 0:
        weather_data.iloc[i,12] = 'Day'
    else:
        weather_data.iloc[i,12] = 'Night'
weather_data.dtypes
weather_data.head()

weather_data['Absolute Latitude'] = abs(weather_data['Lat'])
weather_data.head()
# Out:
#               City  Humidity  Min Temp  Max Temp  Wind Speed  Cloudiness  \
# 0  Arraial do Cabo        49     31.00     33.00        6.20           0
# 1        Carnarvon        11     31.43     31.43        5.01          80
# 2    Mar del Plata        38     20.48     20.48        9.96          32
# 3        Busselton       100     19.40     19.40       10.86           0
# 4           Albany        55    -13.00     -8.30        3.60          75
#
#          Date Country     Sunrise      Sunset    Lat     Lon Daytime  \
# 0  1546869600      BR  1546848622  1546897113 -22.97  -42.02     Day
# 1  1546872328      ZA  1546832178  1546882753 -30.97   22.13     Day
# 2  1546872328      AR  1546850905  1546907055 -46.43  -67.52     Day
# 3  1546872328      AU  1546809400  1546860770 -33.64  115.35   Night
# 4  1546869240      US  1546863893  1546897101  42.65  -73.75     Day
#
#    Absolute Latitude
# 0              22.97
# 1              30.97
# 2              46.43
# 3              33.64
# 4              42.65

# %% [markdown]
# ### Testing the distribution of the random cities by plotting latitude/longitude
#
# * The land masses of the world have been plotted here. http://andywoodruff.com/blog/land-by-latitude-and-longitude-or-a-pile-of-continents/
# * Let's see how our random list of cities compares. Is it representative of the world's land masses?

# %%
sbn.scatterplot(data=weather_data, x='Lat', y='Lon', hue='Daytime', legend=False)
fig = plt.gcf()
fig.set_size_inches(10, 8)
fig.ylimit=(-60,45)
fig.xlimit=(-65,85)
plt.grid(alpha=0.4)
plt.title("Longitude vs. Latitude")
# Out:
# Text(0.5, 1.0, 'Longitude vs. Latitude')

# %%
# response = 'city.list.json'

# owm_city_df = pd.read_json(response, convert_dates=True, encoding='UTF-8')

# %%
# data = owm_city_df['coord'].to_dict()
# lat = []
# lon = []
# df = pd.DataFrame()
# df['OWMLat'] = ''
# df['OWMLon'] = ''
# #Probably can just use a numpy random range for this...
# for i in data:
#     lat.append(data[i]['lat'])
#     lon.append(data[i]['lon'])

# df['OWMLat'] = lat
# df['OWMLon'] = lon
# dfs = df.sample(frac=0.01, replace=True)
# dfs.to_csv('owm_cities_sample.csv', encoding='utf-8', index=False, header=True)

# %%
df_sample = pd.read_csv('owm_cities_sample.csv', encoding='utf-8')
sbn.scatterplot(data=df_sample, x='OWMLat', y='OWMLon')
fig = plt.gcf()
fig.set_size_inches(10, 8)
fig.ylimit=(-60,45)
fig.xlimit=(-65,85)
plt.grid(alpha=0.4)
plt.title("OWM City Distribution")
# plt.legend(loc='best')
# plt.savefig('seaborn_temp_lat.png')
# Out:
# Text(0.5, 1.0, 'OWM City Distribution')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
sbn.lmplot(data=weather_data, x='Absolute Latitude', y='Max Temp', hue='Daytime', legend=True)
fig = plt.gcf()
fig.set_size_inches(10, 8)
fig.ylimit=(-60,45)
fig.xlimit=(-65,85)
plt.grid(alpha=0.4)
plt.title("Latitude vs. Temperature")
# plt.legend(loc='best')
plt.savefig('seaborn_temp_lat.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
sbn.lmplot(data=weather_data, x='Lat', y='Humidity', hue='Daytime', legend=True)
fig = plt.gcf()
fig.set_size_inches(10, 8)
plt.grid(alpha=0.4)
plt.title("Latitude vs. Humidity")
# plt.legend(loc='best')
plt.savefig('seaborn_humid_lat.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
sbn.scatterplot(data=weather_data, x='Lat', y='Cloudiness', hue='Daytime')
fig = plt.gcf()
fig.set_size_inches(10, 8)
fig.ylimit=(-60,45)
fig.xlimit=(-65,85)
plt.grid(alpha=0.4)
plt.title("Latitude vs. Cloudiness")
# plt.legend(loc='best')
plt.savefig('seaborn_cloud_lat.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
sbn.lmplot(data=weather_data, x='Max Temp', y='Wind Speed', hue='Daytime', legend=True)
fig = plt.gcf()
fig.set_size_inches(10, 8)
fig.ylimit=(-60,45)
fig.xlimit=(-65,85)
plt.grid(alpha=0.4)
plt.title("Latitude vs. Wind Speed")
# plt.legend(loc='best')
plt.savefig('seaborn_wind_lat.png')
